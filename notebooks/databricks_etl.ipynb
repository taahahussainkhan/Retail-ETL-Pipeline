# %%
from pyspark.sql.functions import col, isnan, when, count

# %%
df_sales = spark.read.option("header", True).csv("s3a://retail-data-pipeline-taaha/raw/retail_sales_dataset.csv")
df_customers = spark.read.json("s3a://retail-data-pipeline-taaha/raw/MOCK_DATA.json")
df_inventory = spark.read.option("header", True).csv("s3a://retail-data-pipeline-taaha/raw/Sample - Superstore.csv")

# %%
df_customers.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- email: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- isPremium: boolean (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- signup_date: string (nullable = true)

# %%
df_customers.select([count(when(col(c).isNull(), c)).alias(c) for c in df_customers.columns]).show()
# Out:
# +---------------+-------+-----------+-----+----------+------+---------+---------+-----------+
# |_corrupt_record|country|customer_id|email|first_name|gender|isPremium|last_name|signup_date|
# +---------------+-------+-----------+-----+----------+------+---------+---------+-----------+
# |            999|      1|          1|    1|         1|     1|        1|        1|          1|
# +---------------+-------+-----------+-----+----------+------+---------+---------+-----------+
